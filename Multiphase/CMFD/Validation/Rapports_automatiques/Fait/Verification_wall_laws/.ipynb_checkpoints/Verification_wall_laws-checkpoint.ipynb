# %% [markdown]
# # Vérification du codage du gradient de vitesse et de la vorticite

# %%
from trustutils import run 
from trustutils import visit
from trustutils.jupyter import plot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

run.introduction("C. Reiss","16/03/2022")
run.description(r'Validation des lois de paroi implementees dans trioCMFD')

run.description(r'On fait un pas de temps sur un canal long dans la direction de $y$. La condition initiale de vitesse est $v_x=0$, $v_y=1$, $v_z=0$. Par consequent, a une même distance du bord, on a une variation de $y_+$ car on a une variation de $u_{\parallel}$. On calcule analytiquement $u_\tau$, $k_+$, $\tau_+$, $\omega_+$ et $\theta_+$ en fonction de $y_+$. On prend une sonde de la valeur des operateurs de diffusion le long du canal. On verifie que les valeurs de $k_+$, $\theta_+$, $\tau_+$, $\omega_+$ et le taux de cisaillement calculees par triocfd et injectees par les lois de paroi dans les operateurs de diffusion de la vitesse, de la temperature et des quantites turbulentes correspondent aux valeurs analytiques.')

run.TRUST_parameters()
# Out:
# ## Introduction
#  Validation made by : C. Reiss
#  Report created : 16/03/2022
#  Report generated 31/03/2022
# ### Description
# Validation des lois de paroi implementees dans trioCMFD
# ### Description
# On fait un pas de temps sur un canal long dans la direction de $y$. La condition initiale de vitesse est $v_x=0$, $v_y=1$, $v_z=0$. Par consequent, a une même distance du bord, on a une variation de $y_+$ car on a une variation de $u_{\parallel}$. On calcule analytiquement $u_\tau$, $k_+$, $\tau_+$, $\omega_+$ et $\theta_+$ en fonction de $y_+$. On prend une sonde de la valeur des operateurs de diffusion le long du canal. On verifie que les valeurs de $k_+$, $\theta_+$, $\tau_+$, $\omega_+$ et le taux de cisaillement calculees par triocfd et injectees par les lois de paroi dans les operateurs de diffusion de la vitesse, de la temperature et des quantites turbulentes correspondent aux valeurs analytiques.
# ### TRUST parameters
#  * Version TRUST: 1.8.5_beta
# ...

# %%
from trustutils import run 

c1 = run.addCase("K_TAU","K_TAU.data")
c2 = run.addCase("K_OMEGA","K_OMEGA.data")

run.printCases()
run.runCases()
# Out:
# ### Test cases
# * K_TAU/K_TAU.data :
# * K_OMEGA/K_OMEGA.data :
# Running ...
#   => A total of 2 cases were (successfully) run in 27.2s.

# %% [markdown]
# ## Raw extracts from TrioCFD calculation

# %%
mu = 2.3
rho = 3.4
lambd = 4.8
Cp = 2.7
nu = mu/rho
B_w = 0.075
B_k = 0.09

k_init = 3.1
tau_init = 0.7
omega_init = 1/0.7

nuT = lambd/(rho*Cp) + 0.67*k_init*tau_init
nuk=nu + 0.67*k_init*tau_init
nutau = nu + 0.5*k_init*tau_init

deltaT = 4.8

abscisse = np.linspace(0.5,1999.5, 2000)
z = 0.5
k = 1
tau = 1
u_par = 1
Pr = mu*Cp/lambd

surface_face = 1
volume_elem = 1

vx = np.array(plot.loadText("K_TAU/K_TAU_VITESSEX.son")[1::,0])
vy = np.array(plot.loadText("K_TAU/K_TAU_VITESSEY.son")[1::,0])
vz = np.array(plot.loadText("K_TAU/K_TAU_VITESSEZ.son")[1::,0])

vx_o = np.array(plot.loadText("K_OMEGA/K_OMEGA_VITESSEX.son")[1::,0])
vy_o = np.array(plot.loadText("K_OMEGA/K_OMEGA_VITESSEY.son")[1::,0])
vz_o = np.array(plot.loadText("K_OMEGA/K_OMEGA_VITESSEZ.son")[1::,0])

diffT = np.array(plot.loadText("K_TAU/K_TAU_DIFF_T.son")[1::,-1])
diffk = np.array(plot.loadText("K_TAU/K_TAU_DIFF_K.son")[1::,-1])
difftau=np.array(plot.loadText("K_TAU/K_TAU_DIFF_TAU.son")[1::,-1])

diffT_o = np.array(plot.loadText("K_OMEGA/K_OMEGA_DIFF_T.son")[1::,-1])
diffk_o = np.array(plot.loadText("K_OMEGA/K_OMEGA_DIFF_K.son")[1::,-1])
diffomega=np.array(plot.loadText("K_OMEGA/K_OMEGA_DIFF_OMEGA.son")[1::,-1])

diffvitx = np.array(plot.loadText("K_TAU/K_TAU_DIFF_VIT.son")[1::3,1])
diffvity = np.array(plot.loadText("K_TAU/K_TAU_DIFF_VIT.son")[2::3,1])
diffvitz = np.array(plot.loadText("K_TAU/K_TAU_DIFF_VIT.son")[3::3,1])

diffvitx_o = np.array(plot.loadText("K_TAU/K_TAU_DIFF_VIT.son")[1::3,1])
diffvity_o = np.array(plot.loadText("K_TAU/K_TAU_DIFF_VIT.son")[2::3,1])
diffvitz_o = np.array(plot.loadText("K_TAU/K_TAU_DIFF_VIT.son")[3::3,1])

plt.figure(figsize = (12,12))

plt.subplot(331)
plt.plot(abscisse, vx, 'xg', label = r'$k-\tau$')
plt.plot(abscisse, vx_o, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'speed along x-axis')
plt.xlabel('position along y-axis')
plt.legend()

plt.subplot(332)
plt.plot(abscisse, vy, 'xg', label = r'$k-\tau$')
plt.plot(abscisse, vy_o, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'speed along y-axis')
plt.xlabel('position along y-axis')
plt.legend()

plt.subplot(333)
plt.plot(abscisse, vz, 'xg', label = r'$k-\tau$')
plt.plot(abscisse, vz_o, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'speed along z-axis')
plt.xlabel('position along y-axis')
plt.legend()


plt.subplot(334)
plt.plot(abscisse, diffvitx, 'xg', label = r'$k-\tau$')
plt.plot(abscisse, diffvitx_o, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'speed diffusion along x-axis')
plt.xlabel('position along y-axis')
plt.legend()

plt.subplot(335)
plt.plot(abscisse, diffvity, 'xg', label = r'$k-\tau$')
plt.plot(abscisse, diffvity_o, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'speed diffusion long y-axis')
plt.xlabel('position along y-axis')
plt.legend()

plt.subplot(336)
plt.plot(abscisse, diffvitz, 'xg', label = r'$k-\tau$')
plt.plot(abscisse, diffvitz_o, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'speed diffusion along z-axis')
plt.xlabel('position along y-axis')
plt.legend()


plt.subplot(337)
plt.plot(abscisse, diffT, 'xg', label = r'$k-\tau$')
plt.plot(abscisse, diffT_o, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'diffusion of $T$')
plt.xlabel('position along y-axis')
plt.legend()

plt.subplot(338)
plt.plot(abscisse, diffk, 'xg', label = r'$k-\tau$')
plt.plot(abscisse, diffk_o, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'diffusion of $k$')
plt.xlabel('position along y-axis')
plt.legend()

ax1 = plt.subplot(339)

ax1.plot(abscisse, difftau, 'xg', label = r'$k-\tau$')
plt.ylabel(r'diffusion of $\tau$')
plt.xlabel('position along y-axis')
plt.legend()
ax2 = ax1.twinx()  
ax2.plot(abscisse, diffomega, 'or', label = r'$k-\omega$', markersize = 1)
plt.ylabel(r'diffusion of $\omega$')
plt.legend()

plt.tight_layout()

# %% [markdown]
# ## Valeurs analytiques de v, k, tau et omega le long d'un bord

# %%
von_karman_ = 0.41
limiteur_y_p = 0.01

def calc_u_tau_loc(y, u_par, nu):
    eps = 1.e-3
    iter_max = 20
    n_iter = 0

    u_tau_1 = 1.
    while to_zero(y, u_tau_1, u_par, nu) < 0 :
        u_tau_1 *= 10
    u_tau_0 = 0.1
    while to_zero(y,  u_tau_0, u_par, nu) > 0 :
        u_tau_0 /= 10
    if u_tau_1 == 1 :
        u_tau_1 = u_tau_0*10
    elif u_tau_0 == 0.1 :
        u_tau_0 = u_tau_1/10
    
    eps = u_tau_0 * eps

    while (abs(u_tau_1-u_tau_0)>eps) and (n_iter <= iter_max):
        f_0 = to_zero(y, (u_tau_0+u_tau_1)/2, u_par, nu)
        if f_0 > 0 :
            u_tau_1 -= (u_tau_1-u_tau_0)/2
        else :
            u_tau_0 += (u_tau_1-u_tau_0)/2
        n_iter+=1

    return u_tau_0;

def to_zero(y, u_tau,u_par, nu) :
    y_p = y*u_tau/nu
    return u_plus_de_y_plus(y_p) - u_par/u_tau

def u_plus_de_y_plus( y_p) :
    reichardt = np.log(1+0.4*y_p)/von_karman_
    reichardt += 7.8
    reichardt += -7.8*np.exp(-y_p/11)
    reichardt += -7.8*y_p/11*np.exp(-y_p/3)

    log_law = np.log(y_p)/von_karman_ + 5.1

    blending = np.tanh( y_p/27*y_p/27*y_p/27*y_p/27)

    return (1-blending)*reichardt + blending*log_law

def deriv_u_plus_de_y_plus(y_p) :
    reichardt = np.log(1+0.4*y_p)/von_karman_ + 7.8 -7.8*np.exp(-y_p/11) -7.8*y_p/11*np.exp(-y_p/3)
    log_law = np.log(y_p)/von_karman_ + 5.1
    blending = np.tanh( y_p/27*y_p/27*y_p/27*y_p/27)

    d_reichardt = 0.4/(1+0.4*y_p)*1/von_karman_
    d_reichardt += 7.8/11*np.exp(-y_p/11)
    d_reichardt += -7.8/11*np.exp(-y_p/3) + 7.8*y_p/33*np.exp(-y_p/3) 
    d_log_law = 1/(y_p)*1/von_karman_
    d_blending = 4/27*(y_p/27*y_p/27*y_p/27)*(1-blending*blending)

    return (1-blending)*d_reichardt - reichardt*d_blending + blending*d_log_law + d_blending*log_law 

def deriv_u_plus_de_y_plus_2(y_p) :
    reichardt = np.log(1+0.4*y_p)/von_karman_ + 7.8 -7.8*np.exp(-y_p/11) -7.8*y_p/11*np.exp(-y_p/3)
    log_law = np.log(y_p)/von_karman_ + 5.1
    blending = np.tanh( y_p/27*y_p/27*y_p/27*y_p/27)
    
    d_reichardt = 0.4/(1+0.4*y_p)*1/von_karman_
    d_reichardt += 7.8/11*np.exp(-y_p/11)
    d_reichardt += -7.8/11*np.exp(-y_p/3) + 7.8*y_p/33*np.exp(-y_p/3)
    d_log_law = 1/(y_p)*1/von_karman_
    d_blending = 4/27*(y_p/27*y_p/27*y_p/27)*(1-blending*blending)
    
    d_2_reichardt = -0.4*0.4/((1+0.4*y_p)*(1+0.4*y_p))*1/von_karman_
    d_2_reichardt += -7.8/(11*11)*np.exp(-y_p/11)
    d_2_reichardt += 7.8/33*np.exp(-y_p/3) + 7.8/33*np.exp(-y_p/3) - 7.8*y_p/99*np.exp(-y_p/3) 
    d_2_log_law = -1/((y_p)*(y_p))*1/von_karman_
    d_2_blending = 3*4/(27*27)*(y_p/27*y_p/27)*(1-blending*blending) + 4/27*(y_p/27*y_p/27*y_p/27)*(-2*d_blending*blending)
    
    rep = (1-blending)*d_2_reichardt-2*d_reichardt*d_blending-reichardt*d_2_blending
    rep += blending*d_2_log_law + 2*d_blending*d_log_law + d_2_blending*log_law
    return rep

def k_plus_de_y_plus(y_p) :
    return omega_plus_de_y_plus(y_p)*(1/deriv_u_plus_de_y_plus(y_p)-1)

def k_plus_de_y_plus_2(y_p) :
    arg = y_p/4
    blending = np.tanh(arg**4)

    return blending*omega_plus_de_y_plus(y_p)*(1/deriv_u_plus_de_y_plus(y_p)-1) + (1-blending)*5e-2*y_p **1.5

def tau_plus_de_y_plus(y_p) :
    return 1/omega_plus_de_y_plus(y_p)

def omega_plus_de_y_plus(y_p) :
    arg = y_p/10
    phi = np.tanh(arg**4)
    w_vis_p = 6/(B_w*y_p**2)
    w_log_p = 1/(B_k**0.5*von_karman_*y_p)
    w_1_p = w_vis_p+w_log_p
    w_2_p = (w_vis_p**1.2+w_log_p**1.2)**(1/1.2)
    return phi * w_1_p + (1-phi)*w_2_p

def theta_plus_de_y_plus(y_p) :
    Gamma = 0.01*(Pr*y_p)**4/(1+5*Pr**3*y_p)
    B = (3.85*Pr**(1/3)-1.3)**2+2.12*np.log(Pr)
    return Pr*y_p*np.exp(-Gamma) + (2.12*np.log(1+y_p)+B)*np.exp(-1/Gamma)


def calc_dyplus_kplus(y_p):
    arg = y_p/10
    phi = np.tanh(arg*arg*arg*arg)
    w_vis_p = 6/(B_w*y_p*y_p)
    w_log_p = 1/(np.sqrt(B_k)*von_karman_*y_p)
    w_1_p = w_vis_p+w_log_p
    w_2_p = (w_vis_p**1.2+w_log_p**1.2)**(1/1.2)
    w = phi * w_1_p + (1-phi)*w_2_p;
    
    d_w_vis = - 12 / (B_w * y_p*y_p*y_p)
    d_w_log = - 1 / ( np.sqrt(B_k) * von_karman_ * y_p*y_p)
    d_w_1 = d_w_vis + d_w_log 
    d_w_2 = ( d_w_vis * w_vis_p**0.2 + d_w_log * w_log_p**0.2)*( w_vis_p**1.2 + w_log_p**1.2)**(1/1.2-1 )
    d_phi = 4/10*(arg*arg*arg)*(1-phi*phi)
    d_w = d_phi * w_1_p + phi * d_w_1 - d_phi * w_2_p + (1-phi) * d_w_2 
    
    d_u_plus   = deriv_u_plus_de_y_plus(y_p)
    d_2_u_plus = deriv_u_plus_de_y_plus_2(y_p)
    return (1/d_u_plus-1)*d_w + w*(-d_2_u_plus)/(d_u_plus*d_u_plus)

def calc_dyplus_kplus_v2(y_p):
    yp2 = y_p+1e-3
    return 1.e3*(omega_plus_de_y_plus(yp2)*(1/deriv_u_plus_de_y_plus(yp2)-1) - omega_plus_de_y_plus(y_p)*(1/deriv_u_plus_de_y_plus(y_p)-1))

def calc_dyplus_kplus_v3(y_p):
    yp2 = y_p+1e-3
    return 1e3*(k_plus_de_y_plus_2(yp2)-k_plus_de_y_plus_2(y_p))

def calc_dyplus_kplus_v4(y_p):
    arg2 = y_p/4.
    phi2 = np.tanh(arg2*arg2*arg2*arg2)
    d_phi2 = arg2*arg2*arg2*(1-phi2*phi2)
    kplus_yppetit = 5.e-2*y_p**1.5
    d_kplus_yppetit = 1.5*5.e-2*y_p**0.5
    return phi2 * calc_dyplus_kplus(y_p) + d_phi2 * k_plus_de_y_plus(y_p) + (1-phi2)*d_kplus_yppetit - d_phi2 * kplus_yppetit


tab = np.array([ i/100 for i in range(1,1000)]+[ i for i in range(10,1000)])

plt.figure(figsize = (15,8))

plt.subplot(241)
plt.plot(tab, u_plus_de_y_plus(tab), label = "Analytical solution")
plt.xscale('log')
plt.xlabel(r"$y_+$")
plt.ylabel(r"$u_+$")
plt.legend()

plt.subplot(242)
plt.plot(tab, deriv_u_plus_de_y_plus(tab), label = "Analytical derivative")
plt.plot(tab, 1.e3*(u_plus_de_y_plus(tab+1.e-3)-u_plus_de_y_plus(tab)), "--", color = "orange",label = "Numerical derivative")
plt.xscale('log')
plt.xlabel(r"$y_+$")
plt.ylabel(r"$\partial_{y_+}u_+$")
plt.legend()

plt.subplot(243)
plt.plot(tab, -deriv_u_plus_de_y_plus_2(tab), label = "Analytical derivative")
plt.plot(tab, -1e3*(deriv_u_plus_de_y_plus(tab+1e-3)-deriv_u_plus_de_y_plus(tab)), "--", color = "orange", label = "Numerical derivative")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r"$y_+$")
plt.ylabel(r"$\partial_{y_+}\partial_{y_+}u_+$")
plt.legend()

plt.subplot(244)
plt.plot(tab, theta_plus_de_y_plus(tab))
plt.xscale('log')
plt.xlabel(r"$y_+$")
plt.ylabel(r"$\theta_+$")
plt.tight_layout()
plt.legend()

plt.subplot(245)
plt.plot(tab, k_plus_de_y_plus(tab),'b', label = "Kalitzin proposal")
plt.plot(tab, k_plus_de_y_plus_2(tab), "--g", label = "Kalitzin proposal with blending")
plt.legend()
plt.xscale('log')
plt.xlabel(r"$y_+$")
plt.ylabel(r"$k_+$")
plt.ylim(0.,6)

plt.subplot(246)
plt.plot(tab, calc_dyplus_kplus(tab),'b', label = "Kalitzin analytical derivative")
plt.plot(tab, calc_dyplus_kplus_v2(tab), "--", color = "orange", label = "Kalitzin numerical derivative")
plt.plot(tab, calc_dyplus_kplus_v3(tab), color = "purple", label = "Blending analytical derivative")
plt.plot(tab, calc_dyplus_kplus_v4(tab), "--g", label = "Blending numerical derivative")
plt.xscale('log')
plt.xlabel(r"$y_+$")
plt.ylabel(r"$\partial_{y_+}k_+$")
plt.ylim(-1,1)
plt.legend()

plt.subplot(247)
plt.plot(tab, tau_plus_de_y_plus(tab), label = "Analytical solution")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r"$y_+$")
plt.ylabel(r"$\tau_+$")
plt.legend()

plt.subplot(248)
plt.plot(tab, omega_plus_de_y_plus(tab), label = "Analytical solution")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r"$y_+$")
plt.ylabel(r"$\omega_+$")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Valeurs des derivees de v, k, tau et omega le long d'un bord

# %%
u_tau_ana = np.zeros(len(abscisse))
for i in range(len(u_tau_ana)):
    u_tau_ana[i] = calc_u_tau_loc(z, vy[i], nu)


y_p_ana = z * u_tau_ana/nu
dyp_kp_ana = 1e3*(k_plus_de_y_plus(y_p_ana+1e-3)-k_plus_de_y_plus(y_p_ana))
dyp_kp_ana2 = calc_dyplus_kplus_v3(y_p_ana)
dyp_taup_ana = 1e3*(tau_plus_de_y_plus(y_p_ana+1e-3)-tau_plus_de_y_plus(y_p_ana))
dyp_omegap_ana = 1e3*(omega_plus_de_y_plus(y_p_ana+1e-3)-omega_plus_de_y_plus(y_p_ana))
thetap_ana = theta_plus_de_y_plus(y_p_ana)

dz_k = -diffk/nuk
dyp_kp = dz_k*nu/u_tau_ana**3

dz_tau = -difftau/nutau
dyp_taup = dz_tau*u_tau_ana

thetap = deltaT* u_tau_ana / diffT 

dz_k_o = -diffk_o/nuk
dyp_kp_o = dz_k_o*nu/u_tau_ana**3

dz_omega = -diffomega/nutau
dyp_omegap = dz_omega*nu**2/u_tau_ana**3

thetap_o = deltaT* u_tau_ana / diffT_o

shear_stress = -diffvity * rho
shear_stress_o = -diffvity_o * rho
shear_stress_ana = rho * u_tau_ana**2

fig = plt.figure(figsize=(15,8))

plt.subplot(241)
plt.plot(y_p_ana, dyp_kp, 'xg', label = r'trust $k-\tau$')
plt.plot(y_p_ana, dyp_kp_ana2, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\partial_{y_+}k_+$')
plt.xscale('log')
plt.ylim(-1,1)
plt.legend()

plt.subplot(242)
plt.plot(y_p_ana, dyp_taup,'xg', label = r'trust $k-\tau$')
plt.plot(y_p_ana, dyp_taup_ana, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\partial_{y_+}\tau_+$')
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.subplot(243)
plt.plot(y_p_ana, thetap,'xg', label = r'trust $k-\tau$')
plt.plot(y_p_ana, thetap_ana, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\theta_+$')
plt.xscale('log')
plt.legend()

plt.subplot(244)
plt.plot(y_p_ana, shear_stress,'xg', label = r'trust $k-\tau$')
plt.plot(y_p_ana, shear_stress_ana, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'shear stress')
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.subplot(245)
plt.plot(y_p_ana, dyp_kp_o, 'or', label = r'trust $k-\omega$', markersize = 1)
plt.plot(y_p_ana, dyp_kp_ana2, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\partial_{y_+}k_+$')
plt.xscale('log')
plt.ylim(-1,1)
plt.legend()

plt.subplot(246)
plt.plot(y_p_ana, -dyp_omegap,'or', label = r'trust $k-\omega$', markersize = 1)
plt.plot(y_p_ana, -dyp_omegap_ana, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$-\partial_{y_+}\omega_+$')
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.subplot(247)
plt.plot(y_p_ana, thetap_o,'or', label = r'trust $k-\omega$', markersize = 1)
plt.plot(y_p_ana, thetap_ana, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\theta_+$')
plt.xscale('log')
plt.legend()

plt.subplot(248)
plt.plot(y_p_ana, shear_stress_o,'or', label = r'trust $k-\omega$', markersize = 1)
plt.plot(y_p_ana, shear_stress_ana, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'shear stress')
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Valeurs de v, k, tau et omega le long d'un bord

# %%
diffT = np.array(plot.loadText("K_TAU/K_TAU_DIFF_T.son")[1::,-1])
diffk = np.array(plot.loadText("K_TAU/K_TAU_DIFF_K.son")[1::,-1])
difftau=np.array(plot.loadText("K_TAU/K_TAU_DIFF_TAU.son")[1::,-1])


y_p_ana = z * u_tau_ana/nu
k_p_ana = k_plus_de_y_plus_2(y_p_ana)
tau_p_ana=tau_plus_de_y_plus(y_p_ana)
omega_p_ana=omega_plus_de_y_plus(y_p_ana)
theta_p_ana = theta_plus_de_y_plus(y_p_ana)

kp = np.zeros(len(abscisse)-1)
kp[-1]= k_p_ana[-1]
for i in range(-2, -len(kp), -1):
    kp[i] = kp[i+1] - dyp_kp[i] * (y_p_ana[i+1]-y_p_ana[i])
    
taup = np.zeros(len(abscisse)-1)
taup[-1]= tau_p_ana[-1]
for i in range(-2, -len(taup), -1):
    taup[i] = taup[i+1] - dyp_taup[i] * (y_p_ana[i+1]-y_p_ana[i])

kp_o = np.zeros(len(abscisse)-1)
kp_o[-1]= k_p_ana[-1]
for i in range(-2, -len(kp_o), -1):
    kp_o[i] = kp_o[i+1] - dyp_kp_o[i] * (y_p_ana[i+1]-y_p_ana[i])
    
omegap = np.zeros(len(abscisse)-1)
omegap[-1]= omega_p_ana[-1]
for i in range(-2, -len(omegap), -1):
    omegap[i] = omegap[i+1] - dyp_omegap[i] * (y_p_ana[i+1]-y_p_ana[i])

    
fig = plt.figure(figsize=(15,8))

plt.subplot(241)
plt.plot(abscisse, u_tau_ana, '-b', label = 'analytique')
plt.xlabel(r'$y$')
plt.ylabel(r'$u_{\tau}$')
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.subplot(242)
plt.plot(y_p_ana[1:], kp, 'xg', label = r'trust $k-\tau$')
plt.plot(y_p_ana[1:], k_p_ana[1:], '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$k_+$')
plt.xscale('log')
plt.legend()

plt.subplot(243)
plt.plot(y_p_ana[1:], taup, 'xg', label = r'trust $k-\tau$')
plt.plot(y_p_ana[1:], tau_p_ana[1:], '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\tau_+$')
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.subplot(244)
plt.plot(y_p_ana, thetap,'xg', label = r'trust $k-\tau$')
plt.plot(y_p_ana, theta_p_ana, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\theta_+$')
plt.xscale('log')
plt.legend()

plt.subplot(245)
plt.plot(abscisse, y_p_ana, '-b', label = 'analytique')
plt.xlabel(r'$y$')
plt.ylabel(r'$y_+$')
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.subplot(246)
plt.plot(y_p_ana[1:], kp_o, 'ro', label = r'trust $k-\omega$', markersize = 1)
plt.plot(y_p_ana[1:], k_p_ana[1:], '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$k_+$')
plt.xscale('log')
plt.legend()

plt.subplot(247)
plt.plot(y_p_ana[1:], omegap, 'ro', label = r'trust $k-\omega$', markersize = 1)
plt.plot(y_p_ana[1:], omega_p_ana[1:], '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\omega+$')
plt.xscale('log')
plt.yscale('log')
plt.legend()

plt.subplot(248)
plt.plot(y_p_ana, thetap_o,'ro', label = r'trust $k-\omega$', markersize = 1)
plt.plot(y_p_ana, theta_p_ana, '-b', label = 'analytique')
plt.xlabel(r'$y_+$')
plt.ylabel(r'$\theta_+$')
plt.xscale('log')
plt.legend()

plt.tight_layout()

plt.show()
